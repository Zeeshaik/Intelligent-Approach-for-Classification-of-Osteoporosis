# %%
# %pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.9/dist-packages (2.12.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow) (67.6.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.7)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.53.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow) (0.0.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (6.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.12.0

# %% [markdown]
# #Data Pre-Processing

# %%
import cv2,os
data_path='/content/drive/MyDrive/DATASET'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels)) #empty dictionary
print(label_dict)
print(categories)
print(labels)
# Out:
# {'Normal': 0, 'Doubtful': 1, 'Moderate': 2, 'Mild': 3, 'Severe': 4}
# ['Normal', 'Doubtful', 'Moderate', 'Mild', 'Severe']
# [0, 1, 2, 3, 4]

# %%
img_size=256
data=[]
label=[]

for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)
        
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)
        try:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  
            resized=cv2.resize(gray,(img_size,img_size))
            #resizing the image  into 256 x 256, since we need a fixed common size for all the images in the dataset
            data.append(resized)
            label.append(label_dict[category])
            #appending the image and the label(categorized) into the list (dataset)
        except Exception as e:
            print('Exception:',e)
            #if any exception rasied, the exception will be printed here. And pass to the next image

# %% [markdown]
# #Rescale and Assign Categorical Label

# %%
import numpy as np
data=np.array(data)/255.0
data=np.reshape(data,(data.shape[0],img_size,img_size,1))
label=np.array(label)
from keras.utils import np_utils
new_label=np_utils.to_categorical(label)

# %%
new_label.shape
# Out:
# (3651, 5)

# %%
data.shape
# Out:
# (3651, 256, 256, 1)

# %%
data.shape[1:]
# Out:
# (256, 256, 1)

# %% [markdown]
# #CNN Model

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint

model=Sequential()

model.add(Conv2D(128,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The first CNN layer followed by Relu and MaxPooling layers

model.add(Conv2D(64,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The second convolution layer followed by Relu and MaxPooling layers

model.add(Conv2D(32,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The thrid convolution layer followed by Relu and MaxPooling layers

model.add(Flatten())
#Flatten layer to stack the output convolutions from 3rd convolution layer
model.add(Dropout(0.2))

model.add(Dense(128,activation='relu'))
#Dense layer of 128 neurons

model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
#Dense layer of 64 neurons

model.add(Dense(5,activation='softmax'))
#The Final layer with two outputs for two categories

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 128)     1280
#
#  activation (Activation)     (None, 254, 254, 128)     0
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 128)    0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      73792
#
#  activation_1 (Activation)   (None, 125, 125, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 32)        18464
#
#  activation_2 (Activation)   (None, 60, 60, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dropout (Dropout)           (None, 28800)             0
#
#  dense (Dense)               (None, 128)               3686528
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 3,788,645
# Trainable params: 3,788,645
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Splitting Data into Training and Testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data,new_label,test_size=0.1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(20):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(np.squeeze(x_test[i]))
    plt.xlabel(categories[np.argmax(y_test[i])])
plt.show()

# %% [markdown]
# #Training the Model

# %%
history=model.fit(x_train,y_train, epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 83/83 [==============================] - 27s 146ms/step - loss: 1.4824 - accuracy: 0.3581 - val_loss: 1.4309 - val_accuracy: 0.3820
# Epoch 2/100
# 83/83 [==============================] - 10s 120ms/step - loss: 1.3930 - accuracy: 0.3866 - val_loss: 1.3749 - val_accuracy: 0.4064
# Epoch 3/100
# 83/83 [==============================] - 10s 120ms/step - loss: 1.3376 - accuracy: 0.4159 - val_loss: 1.3513 - val_accuracy: 0.4140
# Epoch 4/100
# 83/83 [==============================] - 10s 119ms/step - loss: 1.2799 - accuracy: 0.4498 - val_loss: 1.3063 - val_accuracy: 0.4247
# Epoch 5/100
# 83/83 [==============================] - 10s 121ms/step - loss: 1.2122 - accuracy: 0.4833 - val_loss: 1.2315 - val_accuracy: 0.4764
# Epoch 6/100
# 83/83 [==============================] - 10s 121ms/step - loss: 1.0576 - accuracy: 0.5662 - val_loss: 1.1744 - val_accuracy: 0.5068
# Epoch 7/100
# 83/83 [==============================] - 10s 124ms/step - loss: 0.9910 - accuracy: 0.5970 - val_loss: 1.1344 - val_accuracy: 0.5236
# Epoch 8/100
# 83/83 [==============================] - 11s 129ms/step - loss: 0.7782 - accuracy: 0.6918 - val_loss: 1.0048 - val_accuracy: 0.5951
# Epoch 9/100
# 83/83 [==============================] - 11s 129ms/step - loss: 0.6124 - accuracy: 0.7614 - val_loss: 0.7759 - val_accuracy: 0.7275
# Epoch 10/100
# 83/83 [==============================] - 10s 123ms/step - loss: 0.4285 - accuracy: 0.8459 - val_loss: 0.7661 - val_accuracy: 0.7671
# Epoch 11/100
# 83/83 [==============================] - 10s 122ms/step - loss: 0.3227 - accuracy: 0.8877 - val_loss: 0.7359 - val_accuracy: 0.7702
# Epoch 12/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.2326 - accuracy: 0.9254 - val_loss: 0.6743 - val_accuracy: 0.8128
# Epoch 13/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.1520 - accuracy: 0.9517 - val_loss: 0.6952 - val_accuracy: 0.8265
# Epoch 14/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.1418 - accuracy: 0.9559 - val_loss: 0.6678 - val_accuracy: 0.8432
# Epoch 15/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.1221 - accuracy: 0.9593 - val_loss: 0.8227 - val_accuracy: 0.8524
# Epoch 16/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.1004 - accuracy: 0.9684 - val_loss: 0.8159 - val_accuracy: 0.8493
# Epoch 17/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.1037 - accuracy: 0.9677 - val_loss: 0.7429 - val_accuracy: 0.8691
# Epoch 18/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0688 - accuracy: 0.9833 - val_loss: 0.7062 - val_accuracy: 0.8584
# Epoch 19/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0730 - accuracy: 0.9756 - val_loss: 0.8625 - val_accuracy: 0.8508
# Epoch 20/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0528 - accuracy: 0.9829 - val_loss: 0.8285 - val_accuracy: 0.8600
# Epoch 21/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0467 - accuracy: 0.9878 - val_loss: 0.7593 - val_accuracy: 0.8691
# Epoch 22/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0529 - accuracy: 0.9821 - val_loss: 0.9020 - val_accuracy: 0.8493
# Epoch 23/100
# 83/83 [==============================] - 10s 122ms/step - loss: 0.0385 - accuracy: 0.9893 - val_loss: 0.8513 - val_accuracy: 0.8752
# Epoch 24/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0392 - accuracy: 0.9871 - val_loss: 0.8546 - val_accuracy: 0.8569
# Epoch 25/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0455 - accuracy: 0.9855 - val_loss: 0.9086 - val_accuracy: 0.8615
# Epoch 26/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0335 - accuracy: 0.9871 - val_loss: 0.9498 - val_accuracy: 0.8569
# Epoch 27/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0471 - accuracy: 0.9829 - val_loss: 0.9679 - val_accuracy: 0.8584
# Epoch 28/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0372 - accuracy: 0.9882 - val_loss: 0.9387 - val_accuracy: 0.8569
# Epoch 29/100
# 83/83 [==============================] - 11s 128ms/step - loss: 0.0380 - accuracy: 0.9863 - val_loss: 0.7994 - val_accuracy: 0.8676
# Epoch 30/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0414 - accuracy: 0.9852 - val_loss: 0.8158 - val_accuracy: 0.8600
# Epoch 31/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0309 - accuracy: 0.9874 - val_loss: 0.8425 - val_accuracy: 0.8584
# Epoch 32/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0264 - accuracy: 0.9893 - val_loss: 0.8735 - val_accuracy: 0.8584
# Epoch 33/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0388 - accuracy: 0.9840 - val_loss: 0.8181 - val_accuracy: 0.8615
# Epoch 34/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0385 - accuracy: 0.9825 - val_loss: 0.9998 - val_accuracy: 0.8569
# Epoch 35/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0303 - accuracy: 0.9878 - val_loss: 0.8844 - val_accuracy: 0.8584
# Epoch 36/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0305 - accuracy: 0.9871 - val_loss: 0.9106 - val_accuracy: 0.8584
# Epoch 37/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0358 - accuracy: 0.9855 - val_loss: 0.9474 - val_accuracy: 0.8524
# Epoch 38/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0335 - accuracy: 0.9867 - val_loss: 0.8843 - val_accuracy: 0.8630
# Epoch 39/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0403 - accuracy: 0.9859 - val_loss: 0.9313 - val_accuracy: 0.8645
# Epoch 40/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0695 - accuracy: 0.9783 - val_loss: 1.1111 - val_accuracy: 0.8463
# Epoch 41/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0464 - accuracy: 0.9855 - val_loss: 0.9659 - val_accuracy: 0.8584
# Epoch 42/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0294 - accuracy: 0.9893 - val_loss: 1.0507 - val_accuracy: 0.8493
# Epoch 43/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0323 - accuracy: 0.9886 - val_loss: 1.0994 - val_accuracy: 0.8676
# Epoch 44/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0320 - accuracy: 0.9867 - val_loss: 0.9188 - val_accuracy: 0.8615
# Epoch 45/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0401 - accuracy: 0.9855 - val_loss: 1.0262 - val_accuracy: 0.8600
# Epoch 46/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0293 - accuracy: 0.9878 - val_loss: 1.0132 - val_accuracy: 0.8569
# Epoch 47/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0349 - accuracy: 0.9878 - val_loss: 0.9533 - val_accuracy: 0.8615
# Epoch 48/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0343 - accuracy: 0.9890 - val_loss: 0.9669 - val_accuracy: 0.8584
# Epoch 49/100
# 83/83 [==============================] - 11s 128ms/step - loss: 0.0500 - accuracy: 0.9867 - val_loss: 0.8365 - val_accuracy: 0.8508
# Epoch 50/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0254 - accuracy: 0.9912 - val_loss: 0.9737 - val_accuracy: 0.8584
# Epoch 51/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0325 - accuracy: 0.9886 - val_loss: 0.9517 - val_accuracy: 0.8554
# Epoch 52/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0295 - accuracy: 0.9882 - val_loss: 1.0648 - val_accuracy: 0.8630
# Epoch 53/100
# 83/83 [==============================] - 11s 128ms/step - loss: 0.0299 - accuracy: 0.9867 - val_loss: 1.1645 - val_accuracy: 0.8630
# Epoch 54/100
# 83/83 [==============================] - 10s 119ms/step - loss: 0.0428 - accuracy: 0.9836 - val_loss: 1.1780 - val_accuracy: 0.8508
# Epoch 55/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0384 - accuracy: 0.9859 - val_loss: 1.0278 - val_accuracy: 0.8706
# Epoch 56/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0232 - accuracy: 0.9893 - val_loss: 0.9349 - val_accuracy: 0.8752
# Epoch 57/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0300 - accuracy: 0.9874 - val_loss: 0.9747 - val_accuracy: 0.8691
# Epoch 58/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0232 - accuracy: 0.9897 - val_loss: 1.0525 - val_accuracy: 0.8554
# Epoch 59/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0395 - accuracy: 0.9844 - val_loss: 0.9884 - val_accuracy: 0.8645
# Epoch 60/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0394 - accuracy: 0.9886 - val_loss: 1.0026 - val_accuracy: 0.8524
# Epoch 61/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0249 - accuracy: 0.9901 - val_loss: 1.0378 - val_accuracy: 0.8539
# Epoch 62/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0282 - accuracy: 0.9874 - val_loss: 0.9426 - val_accuracy: 0.8676
# Epoch 63/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0255 - accuracy: 0.9912 - val_loss: 1.0688 - val_accuracy: 0.8539
# Epoch 64/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0202 - accuracy: 0.9901 - val_loss: 1.0582 - val_accuracy: 0.8508
# Epoch 65/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0205 - accuracy: 0.9897 - val_loss: 1.1151 - val_accuracy: 0.8508
# Epoch 66/100
# 83/83 [==============================] - 10s 119ms/step - loss: 0.0169 - accuracy: 0.9924 - val_loss: 1.0408 - val_accuracy: 0.8508
# Epoch 67/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0172 - accuracy: 0.9890 - val_loss: 1.0326 - val_accuracy: 0.8493
# Epoch 68/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0185 - accuracy: 0.9905 - val_loss: 1.0361 - val_accuracy: 0.8569
# Epoch 69/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0145 - accuracy: 0.9928 - val_loss: 1.0590 - val_accuracy: 0.8600
# Epoch 70/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0191 - accuracy: 0.9897 - val_loss: 1.1756 - val_accuracy: 0.8569
# Epoch 71/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0280 - accuracy: 0.9882 - val_loss: 1.0430 - val_accuracy: 0.8508
# Epoch 72/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0172 - accuracy: 0.9905 - val_loss: 1.1600 - val_accuracy: 0.8447
# Epoch 73/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0327 - accuracy: 0.9863 - val_loss: 1.0244 - val_accuracy: 0.8524
# Epoch 74/100
# 83/83 [==============================] - 10s 119ms/step - loss: 0.0208 - accuracy: 0.9905 - val_loss: 1.0111 - val_accuracy: 0.8600
# Epoch 75/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0276 - accuracy: 0.9893 - val_loss: 1.0989 - val_accuracy: 0.8600
# Epoch 76/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0225 - accuracy: 0.9901 - val_loss: 1.0573 - val_accuracy: 0.8524
# Epoch 77/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0270 - accuracy: 0.9874 - val_loss: 1.1745 - val_accuracy: 0.8508
# Epoch 78/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0253 - accuracy: 0.9863 - val_loss: 1.1535 - val_accuracy: 0.8645
# Epoch 79/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0523 - accuracy: 0.9829 - val_loss: 0.9723 - val_accuracy: 0.8584
# Epoch 80/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0311 - accuracy: 0.9855 - val_loss: 1.0371 - val_accuracy: 0.8554
# Epoch 81/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0285 - accuracy: 0.9878 - val_loss: 1.0063 - val_accuracy: 0.8706
# Epoch 82/100
# 83/83 [==============================] - 10s 119ms/step - loss: 0.0203 - accuracy: 0.9912 - val_loss: 1.0164 - val_accuracy: 0.8630
# Epoch 83/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0206 - accuracy: 0.9890 - val_loss: 1.0656 - val_accuracy: 0.8676
# Epoch 84/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0177 - accuracy: 0.9912 - val_loss: 1.1143 - val_accuracy: 0.8569
# Epoch 85/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0234 - accuracy: 0.9882 - val_loss: 1.2396 - val_accuracy: 0.8493
# Epoch 86/100
# 83/83 [==============================] - 10s 119ms/step - loss: 0.0234 - accuracy: 0.9912 - val_loss: 1.1696 - val_accuracy: 0.8661
# Epoch 87/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0292 - accuracy: 0.9897 - val_loss: 1.2103 - val_accuracy: 0.8417
# Epoch 88/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0591 - accuracy: 0.9802 - val_loss: 1.0780 - val_accuracy: 0.8508
# Epoch 89/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0235 - accuracy: 0.9901 - val_loss: 1.0828 - val_accuracy: 0.8402
# Epoch 90/100
# 83/83 [==============================] - 10s 121ms/step - loss: 0.0231 - accuracy: 0.9928 - val_loss: 1.0795 - val_accuracy: 0.8524
# Epoch 91/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0228 - accuracy: 0.9882 - val_loss: 1.0813 - val_accuracy: 0.8630
# Epoch 92/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0172 - accuracy: 0.9916 - val_loss: 1.0283 - val_accuracy: 0.8615
# Epoch 93/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0207 - accuracy: 0.9893 - val_loss: 1.0853 - val_accuracy: 0.8691
# Epoch 94/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0157 - accuracy: 0.9924 - val_loss: 1.0859 - val_accuracy: 0.8600
# Epoch 95/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0204 - accuracy: 0.9897 - val_loss: 1.0352 - val_accuracy: 0.8478
# Epoch 96/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0183 - accuracy: 0.9916 - val_loss: 1.2494 - val_accuracy: 0.8584
# Epoch 97/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0263 - accuracy: 0.9871 - val_loss: 1.0120 - val_accuracy: 0.8752
# Epoch 98/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0236 - accuracy: 0.9905 - val_loss: 1.2513 - val_accuracy: 0.8645
# Epoch 99/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0215 - accuracy: 0.9890 - val_loss: 1.0836 - val_accuracy: 0.8721
# Epoch 100/100
# 83/83 [==============================] - 10s 120ms/step - loss: 0.0205 - accuracy: 0.9874 - val_loss: 1.1142 - val_accuracy: 0.8600

# %%
model.save('model.h5')

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# #Plot the Training Loss and Accuracy

# %%
# plot the training loss and accuracy
N = 100 #number of epochs
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="center right")
plt.savefig("CNN_Model")

# %% [markdown]
# #Testing the Model

# %%
vaL_loss, val_accuracy= model.evaluate(x_test, y_test, verbose=0)
print("test loss:", vaL_loss,'%')
print("test accuracy:", val_accuracy,"%")
# Out:
# test loss: 1.154152512550354 %
# test accuracy: 0.8524590134620667 %

# %%
X = 51

img_size = 256

img_single = x_test[X]
img_single = cv2.resize(img_single, (img_size, img_size))
img_single = (np.expand_dims(img_single, 0))
img_single = img_single.reshape(img_single.shape[0],256,256,1)

predictions_single = model.predict(img_single)
print('A.I predicts:',categories[np.argmax(predictions_single)])
print("Correct prediction for label",np.argmax(y_test[X]),'is',categories[np.argmax(y_test[X])])
plt.imshow(np.squeeze(img_single))
plt.grid(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 X = 51
#       3 img_size = 256
# ----> 5 img_single = x_test[X]
#       6 img_single = cv2.resize(img_single, (img_size, img_size))
#       7 img_single = (np.expand_dims(img_single, 0))
#
# NameError: name 'x_test' is not defined

# %%
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

test_labels = np.argmax(y_test, axis=1)
predictions = model.predict(x_test)
predictions = np.argmax(predictions, axis=-1)


cm  = confusion_matrix(test_labels, predictions)
plt.figure()
plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True,cmap=plt.cm.Blues)
plt.xticks(range(5), ['Normal','Doubtful','Mild','Moderate','Severe'], fontsize=16)
plt.yticks(range(5), ['Normal','Doubtful','Mild','Moderate','Severe'], fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 from mlxtend.plotting import plot_confusion_matrix
#       4 test_labels = np.argmax(y_test, axis=1)
#       5 predictions = model.predict(x_test)
#
# ModuleNotFoundError: No module named 'mlxtend'

# %% [markdown]
# #Testing the Model, By giving Different Images

# %%
from PIL import Image

img_path = '/content/drive/MyDrive/DATASET/Doubtful/DoubtfulG1 (1).png'
img = Image.open(img_path).convert('L')  # convert to grayscale
img = img.resize((img_size, img_size))
img = np.array(img) / 255.0  # normalize pixel values to [0, 1]
img = np.expand_dims(img, axis=0)
img = np.expand_dims(img, axis=-1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 from PIL import Image
#       3 img_path = '/content/drive/MyDrive/DATASET/Doubtful/DoubtfulG1 (1).png'
# ----> 4 img = Image.open(img_path).convert('L')  # convert to grayscale
#       5 img = img.resize((img_size, img_size))
#       6 img = np.array(img) / 255.0  # normalize pixel values to [0, 1]
#
# File ~\anaconda3\lib\site-packages\PIL\Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/DATASET/Doubtful/DoubtfulG1 (1).png'

# %%
predictions_single = model.predict(img)
print(categories[np.argmax(predictions_single)])
plt.imshow(np.squeeze(img))
plt.grid(False)
plt.show()
# Out:
# 1/1 [==============================] - 0s 69ms/step
# Doubtful

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# 12/12 [==============================] - 0s 34ms/step - loss: 1.1542 - accuracy: 0.8525
# Test loss: 1.154152512550354
# Test accuracy: 0.8524590134620667

# %%
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)
accuracy = np.mean(y_pred == np.argmax(y_test, axis=1))
print('Test accuracy:', accuracy)
# Out:
# 12/12 [==============================] - 0s 32ms/step
# Test accuracy: 0.8524590163934426

# %%
import tensorflow as tf

# %%
model = tf.keras.models.load_model('C:/Users/zeesh/OneDrive/Documents/Projects/Intelligent-Approach-for-Classification-of-Osteoporosis/best_model.h5')

# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
img_size = 256
# preprocess the image
categories = ['normal', 'doubtful', 'moderate', 'mild', 'severe']

img_path = 'C:/Users/zeesh/OneDrive/Documents/Projects/Intelligent-Approach-for-Classification-of-Osteoporosis/DataSet/preprocessed_0Normal/20nn.jpg'
img = Image.open(img_path).convert('L')  # convert to grayscale
img = img.resize((img_size, img_size))
img = np.array(img) / 255.0  # normalize pixel values to [0, 1]
img = np.expand_dims(img, axis=0)
img = np.expand_dims(img, axis=-1)

predictions_single = model.predict(img)
print(categories[np.argmax(predictions_single)])
plt.imshow(np.squeeze(img))
plt.grid(False)
plt.show()
# Out:
# 1/1 [==============================] - 5s 5s/step
# normal

# %%
from flask import Flask, render_template, request
from keras.models import load_model
from keras.preprocessing import image
import cv2
import os
import numpy as np

app = Flask(__name__)

data_path = 'C:\\Users\\zeesh\\OneDrive\\Documents\\Projects\\Intelligent-Approach-for-Classification-of-Osteoporosis\\DataSet'
# model_path = '/path/to/your/model.h5'
img_size = 256

# Load the model
# model = load_model(model_path)
model.make_predict_function()

# Load the label dictionary
categories = os.listdir(data_path)
labels = [i for i in range(len(categories))]
label_dict = dict(zip(categories, labels))

def preprocess_image(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    resized = cv2.resize(gray, (img_size, img_size))
    preprocessed_img = np.expand_dims(resized, axis=-1)
    preprocessed_img = preprocessed_img / 255.0
    return preprocessed_img

def predict_label(img):
    preprocessed_img = preprocess_image(img)
    predictions = model.predict(np.array([preprocessed_img]))
    predicted_label = categories[np.argmax(predictions)]
    return predicted_label

@app.route("/", methods=['GET', 'POST'])
def index():
    if request.method == 'POST':
        if 'file' not in request.files:
            return "No file found"
        file = request.files['file']
        img = cv2.imdecode(np.fromstring(file.read(), np.uint8), cv2.IMREAD_UNCHANGED)
        prediction = predict_label(img)
        return prediction
    return render_template("index.html")

if __name__ == '__main__':
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 18
#      15 model.make_predict_function()
#      17 # Load the label dictionary
# ---> 18 categories = os.listdir(data_path)
#      19 labels = [i for i in range(len(categories))]
#      20 label_dict = dict(zip(categories, labels))
#
# NameError: name 'os' is not defined
